# %%
from __future__ import print_function, division

# %matplotlib inline

import thinkdsp
import thinkplot

from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# ### if you have any questions you can contact with me on my [github](https://github.com/wangqiang1983)
# _test the simple classes and their methods_
#
# **using your own code**

# %%
signal = thinkdsp.Chirp(start=220, end=880)
wave1 = signal.make_wave(duration=2)
wave1.plot()

# %%
seg = wave1.segment(start=0,duration=10/1000)
seg.plot()

# %%
seg = wave1.segment(start=500/1000,duration=10/1000)
seg.plot()

# %%
seg = wave1.segment(start=900/1000,duration=10/1000)
seg.plot()

# %%
signal = thinkdsp.ExpoChirp(start=220, end=880)
wave1 = signal.make_wave(duration=1)
wave1.plot()

# %%
seg = wave1.segment(start=0,duration=10/1000)
seg.plot()

# %%
seg = wave1.segment(start=500/1000,duration=10/1000)
seg.plot()

# %%
seg = wave1.segment(start=900/1000,duration=10/1000)
seg.plot()

# %%
sig1 = thinkdsp.Chirp(start=2,end=8)
wav1 = sig1.make_wave(duration=4)
wav1.plot()

# %%
sig1 = thinkdsp.ExpoChirp(start=2,end=8)
wav1 = sig1.make_wave(duration=4)
wav1.plot()
